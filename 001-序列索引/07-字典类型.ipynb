# %% [markdown]
# 字典类型是根据一个信息查找另一个信息的方式， k:v 模式， 也就是 哈希表
#
# 第一种方式，直接 {} 创建
#
# 第二种方式，通过 zip 函数，将两个元组、列表进行合并

# %%
d1 = {10: 'cat', 20: 'dog', 30: 'mouse'}

print(d1)
# Out:
# {10: 'cat', 20: 'dog', 30: 'mouse'}

# %%
lst1 = [10, 20, 40]
lst2 = ['cat', 'dog', 'mouse']
zip_d2 = zip(lst1, lst2)
print(zip_d2)

d3 = dict(zip_d2)
print(d3)
# Out:
# ...
# {10: 'cat', 20: 'dog', 40: 'mouse'}

# %%
# 使用参数创建字典
d4 = dict(cat=10, dog=20)
print(d4)
# Out:
# {'cat': 10, 'dog': 20}

# %%
t = (10, 20, 30)
print({t:10})
# Out:
# {(10, 20, 30): 10}

# %% [markdown]
# 👆 例子说明可以使用元组作为 key

# %%
lst = [10,20,30]
print({lst:10})
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 2
#       1 lst = [10,20,30]
# ----> 2 print({lst:10})
#
# TypeError: unhashable type: 'list'

# %% [markdown]
# 👆 例子说明列表不可以作为 key

# %%
d = {'hello': 10, 'world': 20, 'python': 30}

print(d['hello'])

print(d.get('hello'))
# Out:
# 10
# 10

# %% [markdown]
# 二者之间是有区别的，如果 key 不存在， d[key] 会抛异常， 而 get(key) 可以指定默认值

# %%
print(d.get('java', '不存在'))

print(d['java'])
# Out:
# 不存在
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[4], line 3
#       1 print(d.get('java', '不存在'))
# ----> 3 print(d['java'])
#
# KeyError: 'java'

# %%
for item in d.items():
    print(item)
# Out:
# ('hello', 10)
# ('world', 20)
# ('python', 30)

# %%
for key,value in d.items():
    print(key, value)
# Out:
# hello 10
# world 20
# python 30
