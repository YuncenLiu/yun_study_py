# %% [markdown]
# ## 字符串常用操作
#
# 字符串是 Python 中的不可变数据类型
#
# str.lower(), 将 str 字符串全部转成小写，结果为新字符串
#
# str.upper(), 将 str 字符串全部转成大写字母，结果为新字符串
#
# str.split(sep = None) 把 str 按指定分隔符进行分割，结果为列表类型
#
# str.count(sub) 结果为sub这个字符串在str中出现的次数
#
# str.find(sub) 查询 sub 这个字符串在 str 中是否存在，如果不存在结果为 -1，否则结果为子字符串在 str 首次出现的索引
#
# str.index(sub) 功能与 find 相同，区别在于要查询的子串 sub 不存在时，程序报错
#
# str.startswith(s) 查询 str 是否以 s 开头，结果为布尔值
#
# str.endswith(s) 查询 str 是否以 s 结尾，结果为布尔值

# %%
s1 = 'HelloWorld'
new_s2 = s1.lower()
print(s1, new_s2)
# Out:
# HelloWorld helloworld

# %%
new_s3 = s1.upper()
print(new_s3)
# Out:
# HELLOWORLD

# %%
e_mail = 'ysj@126.com'
lst = e_mail.split('@')
print(lst)
# Out:
# ['ysj', '126.com']

# %%
print(s1.count('o'))
# Out:
# 2

# %%
print(s1.find('o'))
# Out:
# 4

# %%
print(s1.find('V'))
# Out:
# -1

# %%
print('demo.py'.endswith('.py'))
# Out:
# True

# %%
print('Hello'.startswith('H'))
# Out:
# True

# %% [markdown]
# str.replace(old,news), 使用 news 替换字符串s 中所有的 old 字符串，结果是新的字符串
#
# str.center(width, fillchar) 字符串 str 在指定宽度范围内居中，可以使用fillchar 进行填充
#
# str.join(iter) 在 iter 中的每个元素的后面都增加一个新的字符串 str
#
# str.strip(chars) 从字符串中去掉左侧和右侧 chars 中列出的字符串
#
# str.lstrip(chars) 从字符串中去掉左侧 chars 中列出的字符串
#
# str.rstrip(chars) 从字符串中去掉右侧 chars 中列出的字符串

# %%
print('helloWorld'.replace('oW','-->'))
# Out:
# hell-->orld

# %% [markdown]
# 第三个参数表示替换次数

# %%
print('helloWorld'.replace('o','👌',1))
# Out:
# hell👌World

# %%
s = 'helloworld'
print(s.center(20))
# Out:
#      helloworld

# %%
print(s.center(100, '*'))
# Out:
# *********************************************helloworld*********************************************

# %%
s = ' Hello World    '
s1 = 'dl-Helloworld'
print(s.strip())
print(s1.strip('d'))
# Out:
# Hello World
# l-Helloworl

# %%
print(s.lstrip())
s1 = 'dl-Helloworld'
print(s1.lstrip('d'))
# Out:
# Hello World
# l-Helloworld

# %%
print(s.rstrip())
s1 = 'dl-Helloworld'
print(s1.rstrip('d'))
# Out:
#  Hello World
# dl-Helloworl
