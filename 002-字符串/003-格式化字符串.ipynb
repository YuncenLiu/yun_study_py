# %% [markdown]
# 1. 占位符格式化, `%s`字符串格式, `%d` 十进制,`%f` 浮点数
# 2. f-string, `f'{变量名}'` 在 Python3
# 3. str.format()方法, `'{} {}'.format(变量1,变量2)`

# %%
name = '马冬梅'
age = 18
score = 98.5
print('姓名:%s, 年龄:%d, 成绩:%f' % (name, age, score))
print('姓名:%s, 年龄:%d, 成绩:%.1f' % (name, age, score))
# Out:
# 姓名:马冬梅, 年龄:18, 成绩:98.500000
# 姓名:马冬梅, 年龄:18, 成绩:98.5

# %%
print(f'姓名:{name}, 年龄:{age}, 成绩:{score:.1f}')
# Out:
# 姓名:马冬梅, 年龄:18, 成绩:98.5

# %%
print('姓名:{}, 年龄:{}, 成绩:{}'.format(name, age, score))
# Out:
# 姓名:马冬梅, 年龄:18, 成绩:98.5

# %%
print('姓名:{0}, 年龄:{1}, 成绩:{2}'.format(name, age, score))

print('姓名:{2}, 年龄:{0}, 成绩:{1}'.format(age, score, name))
# Out:
# 姓名:马冬梅, 年龄:18, 成绩:98.5
# 姓名:马冬梅, 年龄:18, 成绩:98.5

# %% [markdown]
# #### 格式化字符串的详细格式

# %%
s = 'helloworld'
print('{0:*<20}'.format(s)) # 字符串的显示宽度为 20，左对齐，空白部分使用 * 填充
print('{0:*>20}'.format(s))
print('{0:*^20}'.format(s))
# Out:
# helloworld**********
# **********helloworld
# *****helloworld*****

# %% [markdown]
# 千位分隔符，只适用于整数和浮点数

# %%
print('{0:,}'.format(987654321))
# Out:
# 987,654,321

# %%
print('{0:,}'.format(987654321.123456789))
print('{0:.2f}'.format(3.1415926535))
# Out:
# 987,654,321.1234568
# 3.14

# %%
print('{0:.5}'.format('helloworld'))
# Out:
# hello

# %%
a = 425
print('二进制:{0:b}, 十进制:{0:d}, 八进制:{0:o}, 十六进制:{0:x}, 十六进制:{0:X}'.format(a))
# Out:
# 二进制:110101001, 十进制:425, 八进制:651, 十六进制:1a9, 十六进制:1A9

# %%
b = 3.1414159
print('{0:.2f},{0:.2E},{0:.2e},{0:.2%}'.format(b))
# Out:
# 3.14,3.14E+00,3.14e+00,314.14%
