# %% [markdown]
# ## 合法性验证
#
# str.isdigit() 所有字符都是数字
#
# str.isnumeric() 是否字符都是数字
#
# str.isalpha() 所有字符都是字母（包括中文字符）
#
# str.isalnum() 所有字符都是数字或字母（包含中文字符）
#
# str.islower() 所有字符都是小写
#
# str.isupper() 所有字符都是大写
#
# str.istitle() 所有字符都是首字母大写
#
# str.isspace() 所有字符都是空白字符(\n \t等)

# %%
# str.isdigit() 所有字符都是数字
print('123'.isdigit())
print('一二三'.isdigit())
print('0b1101'.isdigit())
print('ⅠⅠⅠⅠⅠⅠ'.isdigit())
# Out:
# True
# False
# False
# False

# %%
# str.isnumeric() 是否字符都是数字
print('123'.isnumeric())
print('一二三'.isnumeric())
print('0b1101'.isnumeric())
print('ⅠⅠⅠⅠⅠⅠ'.isnumeric())
print('壹贰叁'.isnumeric())
# Out:
# True
# True
# False
# True
# True

# %%
# str.istitle() 所有字符都是首字母大写
print('Hello'.istitle())
print('HelloWorld'.istitle())
print('Helloworld'.istitle())
print('Hello World'.istitle())
# Out:
# True
# False
# True
# True
