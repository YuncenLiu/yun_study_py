# %% [markdown]
# #### 顺序传参

# %%
def say_hello(name, age):
    print(name, '你好👋')
    print(str(age), '岁')


say_hello('章三', 20)
# Out:
# 章三 你好👋
# 20 岁

# %% [markdown]
# #### 关键字传承
#
# 参数名称必须和定义函数中的参数保持一致
#
# 支持同种方式一块使用

# %%
say_hello(age=20, name='张三')
# Out:
# 张三 你好👋
# 20 岁

# %%
say_hello('李四', age=40)
# Out:
# 李四 你好👋
# 40 岁

# %%
say_hello(age=40, '王武')
# Out:
#   Cell In[7], line 1
#     say_hello(age=40, '王武')
#                           ^
# SyntaxError: positional argument follows keyword argument

# %% [markdown]
# ## 默认值参数
#
# 在函数定义时设定

# %%
def say_def_hello(name='张三', age=40):
    print(name, '你好👋')
    print(str(age), '岁')


say_def_hello('李四', 19)
# Out:
# 李四 你好👋
# 19 岁

# %% [markdown]
# 多个参数的默认值传参问题

# %%
def fun1(a, b=20):  # a作为位置传参，b作为默认值
    pass


def func2(a=20, b):  # 报错了，语法错误
    pass
# Out:
#   Cell In[9], line 4
#     def func2(a=20, b): # 报错了，语法错误
#                     ^
# SyntaxError: parameter without a default follows parameter with a default

# %% [markdown]
# ## 可变参数
#
# 分为可变位置参数 和 个数可变关键字参数 两种，其中 个数可变的位置参数是在参数前面加一颗星 (*para) ，para 形式参数的名称，函数调用时可接收人意个数的实际参数，并放到一个元祖中。
#
# 个数可变关键字参数是在参数前面加两颗星 (**para)，在函数调用时可接收多个， “参数 = 值”形式的参数，并放到一个字典中。

# %% [markdown]
# ### 可变位置参数

# %%
def v_fun(*pars):
    print(type(pars))
    for item in pars:
        print(item)

# %%
v_fun(10)
# Out:
# <class 'tuple'>
# 10

# %%
v_fun(20, 30, 40, 50)
# Out:
# <class 'tuple'>
# 20
# 30
# 40
# 50

# %% [markdown]
# 如果直接传递列表，列表会当作一个元素处理

# %%
v_fun([11, 12, 13])
# Out:
# <class 'tuple'>
# [11, 12, 13]

# %% [markdown]
# 如果要拆开处理，可以这样写 v_fun(*[15,16,17])

# %%
v_fun(*[15, 16, 17])
# Out:
# <class 'tuple'>
# 15
# 16
# 17

# %% [markdown]
# ### 个数可变关键字参数

# %%
def v_fun2(**args):
    print(type(args))
    for key, value in args.items():
        print(key, '-----', value)

# %%
v_fun2(name='张三', age=19, hight='170')
# Out:
# <class 'dict'>
# name ----- 张三
# age ----- 19
# hight ----- 170
