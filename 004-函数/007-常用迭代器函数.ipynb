# %% [markdown]
# ### 常用的内置函数
#
# 1. sorted(iter) 对可迭代对象进行排序
# 2. reversed(iter) 对可迭代对象进行倒序
# 3. zip(x1, x2, ...) 创建一个迭代器，迭代器中包含多个元组
# 4. enumerate(iter) 根据 iter 对象创建一个 enumerate 对象
# 5. all(iter) 判断 iter 是否所有元素都为真
# 6. any(iter) 判断 iter 是否至少有一个元素为真
# 7. map(func, iter) 对 iter 中的元素进行 func 函数处理
# 8. filter(func, iter) 对 iter 中的元素进行 func 函数处理，返回结果为真
# 9. map(func, iter) 通过函数function 对可叠戴对象 iter 操作返回一个迭代器对象

# %%
lst = [45, 2, 17, 9, 32, 75, 22]

# %% [markdown]
# 排序操作

# %%
asc_lst = sorted(lst) # 升序
desc_lst = sorted(lst, reverse=True) # 降序

print('原列表', lst)
print('升序', asc_lst)
print('降序', desc_lst)
# Out:
# 原列表 [45, 2, 17, 9, 32, 75, 22]
# 升序 [2, 9, 17, 22, 32, 45, 75]
# 降序 [75, 45, 32, 22, 17, 9, 2]

# %% [markdown]
# 反向

# %%
new_lst = reversed(lst)
print('原列表', lst)
print('反向', list(new_lst))
# Out:
# 原列表 [45, 2, 17, 9, 32, 75, 22]
# 反向 [22, 75, 32, 9, 17, 2, 45]

# %% [markdown]
# zip 打包📦, 最终以短的为标准

# %%
x = ['a', 'b', 'c', 'd']
y = [10, 20, 30, 40, 50]
z = zip(x, y)
print(type(z))
print(list(z))
# Out:
# <class 'zip'>
# [('a', 10), ('b', 20), ('c', 30), ('d', 40)]

# %% [markdown]
# enumerate 枚举

# %%
enum = enumerate(y, start=1)
print(type(enum))
print(tuple(enum))
# Out:
# <class 'enumerate'>
# ((1, 10), (2, 20), (3, 30), (4, 40), (5, 50))

# %% [markdown]
# all()  判断 iter 是否所有元素都为真

# %%
lst2 = [10, 20, '', 40]
print('空字符串的布尔值为: ',all(lst2))
print('列表中的所有元素都不为空时为:',all(lst))
# Out:
# 空字符串的布尔值为:  False
# 列表中的所有元素都不为空时为: True

# %% [markdown]
# any(iter) 判断 iter 是否至少有一个元素为真

# %%
print('空字符串的布尔值为: ',any(lst2))
# Out:
# 空字符串的布尔值为:  True
